# %% [markdown]
# # **Initialize repository**

# %%
#@title Mount drive for initializing git repo

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#@title Change working directory

# %cd '/content/drive/MyDrive/ProcessorTest/'
# %ls
# Out:
# /content/drive/MyDrive/ProcessorTest
# 'Processor GitHub Test.ipynb'

# %%
#@title Initialize git

# !git init colab-github-test
# %cd colab-github-test/
# %ls -a
# Out:
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/drive/MyDrive/ProcessorTest/colab-github-test/.git/
# /content/drive/MyDrive/ProcessorTest/colab-github-test
# .git/

# %%
#@title Test some git commands

# !git config --global user.email "janelletam.work@gmail.com"
# !git config --global user.name "Janelle Tam"

# %%
# !git commit -am "Add processor"
# Out:
# [master f7b9bc8] Add processor
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git status
# Out:
# On branch master
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   Processor GitHub Test.ipynb

# %%
# !git commit -am "Organized demo git commands"
# Out:
# [master fa887a3] Organized demo git commands
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
#@title Attaching remote repository

username = 'janelletam'
git_token = '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'
repository = 'colab-github-test'

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# origin	https://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@github.com/janelletam/colab-github-test.git (fetch)
# origin	https://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@github.com/janelletam/colab-github-test.git (push)

# %%
# !git branch main

# %%
# !git checkout main
# Out:
# M	Processor GitHub Test.ipynb
# Switched to branch 'main'

# %%
# !git branch
# Out:
# * main
#   master

# %%
# !git push -u -f origin main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 3.09 KiB | 105.00 KiB/s, done.
# Total 9 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), done.
# To https://github.com/janelletam/colab-github-test.git
#  + bf9668f...fa887a3 main -> main (forced update)
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git push
